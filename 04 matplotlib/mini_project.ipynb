# %% [markdown]
# **Proyek: Visualisasi Data Cuaca Tahunan**
#
# *Skenario: kita mendapatkan data cuaca rata-rata untuk sebuah kota fiksi selama 12 bulan. Tugas kita adalah membuat beberapa visualisasi untuk membantu memahami pola cuaca di kota tersebut sepanjang tahun.*
#
# ---

# %% [markdown]
# **Data Cuaca**
#
# ***Berikut adalah data yang kita miliki:***
#
# - Bulan: ['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep', 'Okt', 'Nov', 'Des']
#
# - Suhu Rata-rata (°C): [28, 29, 31, 32, 31, 30, 29, 29, 30, 31, 30, 29]
#
# - Curah Hujan (mm): [250, 310, 280, 150, 120, 80, 70, 85, 110, 190, 220, 260]
#
# ___

# %% [markdown]
# **Tantangan Visualisasi:**
#
# 1. Grafik Tren Suhu (Line Plot)
# - Buatlah sebuah grafik garis yang menunjukkan perubahan suhu rata-rata dari bulan Januari hingga Desember.
# - Beri judul: "Tren Suhu Rata-rata Bulanan".
# - Beri label sumbu X: "Bulan".
# - Beri label sumbu Y: "Suhu (°C)".
# - Tampilkan plotnya.
#
# 2. Distribusi Suhu (Histogram)
# - Buatlah sebuah histogram dari data suhu untuk melihat sebaran frekuensi suhunya.
# - Gunakan 4 bins (kelompok) untuk histogram ini. Petunjuk: tambahkan argumen bins=4 di dalam fungsi plt.hist().
# - Beri judul: "Distribusi Frekuensi Suhu".
# - Beri label sumbu X: "Suhu (°C)".
# - Beri label sumbu Y: "Frekuensi (Jumlah Bulan)".
# - Tampilkan plotnya.
#
# 3. Hubungan Suhu dan Curah Hujan (Scatter Plot)
# - Buatlah sebuah scatter plot untuk melihat apakah ada hubungan antara suhu dan curah hujan.
# - Sumbu X: suhu.
# - Sumbu Y: curah_hujan.
# - Beri judul: "Hubungan Suhu dan Curah Hujan".
# - Beri label sumbu X: "Suhu Rata-rata (°C)".
# - Beri label sumbu Y: "Curah Hujan (mm)".
# - Tampilkan plotnya.
#
#
# ----

# %% [markdown]
# **Kode Starter:**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data Cuaca
bulan = ['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep', 'Okt', 'Nov', 'Des']
suhu = np.array([28, 29, 31, 32, 31, 30, 29, 29, 30, 31, 30, 29])
curah_hujan = np.array([250, 310, 280, 150, 120, 80, 70, 85, 110, 190, 220, 260])

# --- TULIS KODE ANDA DI BAWAH INI ---

# %% [markdown]
# ---

# %% [markdown]
# **1. Grafik Tren Suhu (Line Plot)**

# %%
plt.figure(figsize=(16, 4))
plt.plot(bulan, suhu)
plt.title("Tren Suhu Rata-rata Bulanan")
plt.xlabel("Bulan")
plt.ylabel("Suhu (°C)")


plt.show()


#additional
#hitung rata-rata suhu
rata_rata_suhu = np.mean(suhu)
print(f"Rata-rata Suhu: {rata_rata_suhu:.2f} °C")
#hitung median suhu
median_suhu = np.median(suhu)
print(f"Median Suhu: {median_suhu:.2f} °C")
#hitung standar deviasi suhu
std_suhu = np.std(suhu)
print(f"Standar Deviasi Suhu: {std_suhu:.2f} °C")
#hitung varians suhu
var_suhu = np.var(suhu)
print(f"Varians Suhu: {var_suhu:.2f} °C^2")
#hitung range suhu
range_suhu = np.ptp(suhu)
print(f"Range Suhu: {range_suhu:.2f} °C")
#hitung skewness suhu
skewness_suhu = stats.skew(suhu)
print(f"Skewness Suhu: {skewness_suhu:.2f}")
#hitung kurtosis suhu
kurtosis_suhu = stats.kurtosis(suhu)
print(f"Kurtosis Suhu: {kurtosis_suhu:.2f}")
#hitung quantile suhu
quantile_suhu = np.percentile(suhu, 75)
print(f"Quantile 75% Suhu: {quantile_suhu:.2f} °C")
#hitung interquartile range suhu
iqr_suhu = stats.iqr(suhu)
print(f"Interquartile Range Suhu: {iqr_suhu:.2f} °C")
#hitung covariance suhu dan curah hujan
covariance = np.cov(suhu, curah_hujan)[0, 1]
print(f"Kovarians antara suhu dan curah hujan: {covariance:.2f}")
# Out:
# Rata-rata Suhu: 29.92 °C
# Median Suhu: 30.00 °C
# Standar Deviasi Suhu: 1.11 °C
# Varians Suhu: 1.24 °C^2
# Range Suhu: 4.00 °C
# Skewness Suhu: 0.16
# Kurtosis Suhu: -0.88
# Quantile 75% Suhu: 31.00 °C
# Interquartile Range Suhu: 2.00 °C
# Kovarians antara suhu dan curah hujan: -14.36

# %% [markdown]
# ---

# %% [markdown]
# **2. Distribusi Suhu (Histogram)**

# %%
plt.figure(figsize=(6, 4))
plt.hist(suhu, bins=4)
plt.title("Distribusi Frekuensi Suhu")
plt.xlabel("Suhu (°C)")
plt.ylabel("Frekuensi Jumlah Bulan")


plt.show()

#hitung sebaran suhu
mean_suhu = np.mean(suhu)
median_suhu = np.median(suhu)
std_suhu = np.std(suhu)
print(f"Rata-rata Suhu: {mean_suhu:.2f} °C")
print(f"Median Suhu: {median_suhu:.2f} °C") 
print(f"Standar Deviasi Suhu: {std_suhu:.2f} °C")
# Out:
# Rata-rata Suhu: 29.92 °C
# Median Suhu: 30.00 °C
# Standar Deviasi Suhu: 1.11 °C

# %% [markdown]
# **3. Hubungan Suhu dan Curah Hujan (Scatter Plot)**

# %%
plt.figure(figsize=(6, 4))
plt.scatter(suhu, curah_hujan)
plt.title("Hubungan Suhu dan Curah Hujan")
plt.xlabel("Suhu Rata-rata (°C)")
plt.ylabel("Curah Hujan (mm)")


plt.show()


#hitung korelasi suhu dan curah hujan
korelasi = np.corrcoef(suhu, curah_hujan)[0, 1]
print(f"Korelasi antara suhu dan curah hujan: {korelasi:.2f}")
# Out:
# Korelasi antara suhu dan curah hujan: -0.14

# %% [markdown]
# **4. Additional**

# %%
#hitung rata-rata suhu
rata_rata_suhu = np.mean(suhu)
print(f"Rata-rata Suhu Rata-rata Bulanan: {rata_rata_suhu:.2f} °C")

# pada bulan apa suhu tertinggi dan terendah
bulan_tertinggi = bulan[np.argmax(suhu)]
bulan_terendah = bulan[np.argmin(suhu)]
print(f"Bulan dengan Suhu Tertinggi: {bulan_tertinggi}")
print(f"Bulan dengan Suhu Terendah: {bulan_terendah}")
# Out:
# Rata-rata Suhu Rata-rata Bulanan: 29.92 °C
# Bulan dengan Suhu Tertinggi: Apr
# Bulan dengan Suhu Terendah: Jan

# %%
# hitung rata-rata curah hujan
rata_rata_curah_hujan = np.mean(curah_hujan)    
print(f"Rata-rata Curah Hujan Bulanan: {rata_rata_curah_hujan:.2f} mm")

# gunakan slicing untuk menghitung rata-rata curah hujan per semester
semester_1 = curah_hujan[:6]
semester_2 = curah_hujan[6:]
rata_rata_semester_1 = np.mean(semester_1)
rata_rata_semester_2 = np.mean(semester_2)
print(f"Rata-rata Curah Hujan Semester 1: {rata_rata_semester_1:.2f} mm")
print(f"Rata-rata Curah Hujan Semester 2: {rata_rata_semester_2:.2f} mm")


# pada bulan apa curah hujan tertinggi dan terendah
bulan_curah_hujan_tertinggi = bulan[np.argmax(curah_hujan)]
bulan_curah_hujan_terendah = bulan[np.argmin(curah_hujan)]
print(f"Bulan dengan Curah Hujan Tertinggi: {bulan_curah_hujan_tertinggi}")
print(f"Bulan dengan Curah Hujan Terendah: {bulan_curah_hujan_terendah}")
# Out:
# Rata-rata Curah Hujan Bulanan: 177.08 mm
# Rata-rata Curah Hujan Semester 1: 198.33 mm
# Rata-rata Curah Hujan Semester 2: 155.83 mm
# Bulan dengan Curah Hujan Tertinggi: Feb
# Bulan dengan Curah Hujan Terendah: Jul

# %%
#another way to store data
import pandas as pd

df = pd.DataFrame({
    'bulan': ['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep', 'Okt', 'Nov', 'Des'],
    'curah_hujan': np.array([250, 310, 280, 150, 120, 80, 70, 85, 110, 190, 220, 260])
})

# Tambahkan kolom semester
df['Semester'] = ['Semester 1'] * 6 + ['Semester 2'] * 6

# Gunakan groupby
rata_rata = df.groupby('Semester')['curah_hujan'].mean()

print(rata_rata)
# Out:
# Semester
# Semester 1    198.333333
# Semester 2    155.833333
# Name: curah_hujan, dtype: float64
